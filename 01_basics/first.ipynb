# %% [markdown]
# ## Learning numpy

# %%
import numpy as np

# %% [markdown]
# Creating array from the list

# %%
# Creating one dimenstional array
arr = np.array([1,2,3,4,5,6])
print("one dimensional array is : ", arr)

# %%
# two dimensional array is : 
arr2 = np.array([[1,2,3],[4,5,6]])
print("this is a two dimensional array : ", arr2)

# %% [markdown]
# ## Python list vs Numpy Array

# %%
arr_of_py = [1,2,3,4]
print("we are going to multiplicate the list : ",arr_of_py*2)
# Out:
# we are going to multiplicate the list :  [1, 2, 3, 4, 1, 2, 3, 4]

# %%
arr_of_numpy = np.array([1,2,3,4])
print("We also gonna multiply this : ", arr_of_numpy*2)
# Out:
# We also gonna multiply this :  [2 4 6 8]

# %% [markdown]
# We notice that when we mulitply in list it incease the qaunitity of each element
# and in numpy_array it actually multiply with each number
